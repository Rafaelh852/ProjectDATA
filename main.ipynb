# %%
import os

# %%
import os
import pandas as pd
path = "./data"
dbnames = os.listdir(path)
nfile = 0
db = path + "/" + "mentalhealth"
dbfiles = os.listdir(db)
pd.read_csv(db+"/"+dbfiles[nfile])
# Out:
#      Unnamed: 0  Age  Gender  self_employed  family_history treatment  \
# 0             1   37       0              0               0       Yes
# 1             2   44       1              0               0        No
# 2             3   31       1              0               0        No
# 3             4   33       1              0               1        No
# 4             5   35       0              0               1       Yes
# ..          ...  ...     ...            ...             ...       ...
# 742         743   36       1              0               1       Yes
# 743         744   32       1              0               1       Yes
# 744         745   34       1              0               1        No
# 745         746   46       0              0               0        No
# 746         747   25       1              0               1       Yes
#
#      work_interfere  no_employees  remote_work  tech_company  ...  anonymity  \
# ...

# %%
post ="mentalhealth"
path = "./data"
sub = "/"
dbname = post
dbpath = path + sub + dbname
dbfile = os.listdir(dbpath)
pd.read_csv(dbpath + sub + dbfile[0])
# Out:
#      Unnamed: 0  Age  Gender  self_employed  family_history treatment  \
# 0             1   37       0              0               0       Yes
# 1             2   44       1              0               0        No
# 2             3   31       1              0               0        No
# 3             4   33       1              0               1        No
# 4             5   35       0              0               1       Yes
# ..          ...  ...     ...            ...             ...       ...
# 742         743   36       1              0               1       Yes
# 743         744   32       1              0               1       Yes
# 744         745   34       1              0               1        No
# 745         746   46       0              0               0        No
# 746         747   25       1              0               1       Yes
#
#      work_interfere  no_employees  remote_work  tech_company  ...  anonymity  \
# ...
